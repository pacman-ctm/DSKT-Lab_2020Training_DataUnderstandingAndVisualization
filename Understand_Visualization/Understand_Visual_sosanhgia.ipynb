# %%
import pandas as pd
import matplotlib.pyplot as plt   
import matplotlib.ticker as ticker
import numpy as np
import seaborn as sns

# %%
def changeTextToInt(text):
    # Convert text "2.300.000" to int 2300000
    if (type(text) == str):
        return int(float(text.replace(".","")))
    return np.nan

# %%
df = pd.read_csv("sosanhgia.csv")
df
# Out:
#                   category__001        category__002 category__003  \
# 0     Điện lạnh - Điện gia dụng    Gia dụng gia đình   Máy hút bụi
# 1     Điện lạnh - Điện gia dụng    Gia dụng gia đình   Máy hút bụi
# 2     Điện lạnh - Điện gia dụng    Gia dụng gia đình   Máy hút bụi
# 3     Điện lạnh - Điện gia dụng    Gia dụng gia đình   Máy hút bụi
# 4        Máy tính - Thiết bị VP               Laptop   Laptop Asus
# ...                         ...                  ...           ...
# 2738                 Thời trang  Phụ kiện thời trang       Đồng hồ
# 2739                 Thời trang  Phụ kiện thời trang       Đồng hồ
# 2740                 Thời trang  Phụ kiện thời trang       Đồng hồ
# 2741                 Thời trang  Phụ kiện thời trang       Đồng hồ
# 2742                 Thời trang  Phụ kiện thời trang       Đồng hồ
#
#            category__004                                               name  \
# 0      Máy hút bụi  KHÁC          Robot hút bụi thông minh Neato Botvac D85
# 1     Máy hút bụi  Ilife                   Robot hút bụi lau nhà iLife X660
# 2      Máy hút bụi  KHÁC  Robot hút bụi thông minh Neato Botvac Connecte...
# 3      Máy hút bụi  KHÁC  Robot hút bụi thông minh Neato Botvac Connecte...
# 4                    NaN                       Laptop Asus 14 X409FA-EK199T
# ...                  ...                                                ...
# 2738         Đồng hồ nam                   Đồng Hồ Nam Orient RA-KV0005B10B
# 2739         Đồng hồ nam                     Đồng Hồ Nam Reef Tiger RGA823G
# 2740         Đồng hồ nam                        Đồng Hồ Nam Pulsar PS9311X1
# 2741         Đồng hồ nam                     Đồng Hồ Nam Reef Tiger RGA8239
# 2742         Đồng hồ nam                          Đồng Hồ Nam Valence VC059
#
#                                                 img_url   brand  \
# 0     https://img.sosanhgia.com/images/500x0/d5d0e60...    KHÁC
# 1     https://img.sosanhgia.com/images/500x0/450781b...   Ilife
# 2     https://img.sosanhgia.com/images/500x0/c2caa7a...    KHÁC
# 3     https://img.sosanhgia.com/images/500x0/c9ecbce...    KHÁC
# 4     https://img.sosanhgia.com/images/500x0/c3290f2...    Asus
# ...                                                 ...     ...
# 2738  https://img.sosanhgia.com/images/500x0/68374a5...  Orient
# 2739  https://img.sosanhgia.com/images/500x0/8683be8...    KHÁC
# 2740  https://img.sosanhgia.com/images/500x0/eece61e...    KHÁC
# 2741  https://img.sosanhgia.com/images/500x0/5a6b0ae...    KHÁC
# 2742  https://img.sosanhgia.com/images/500x0/358f641...    KHÁC
#
#                                              short_desc priority_price  \
# 0     -- Công nghệ làm sạch SpinFlow Power Clean \n ...     14.200.000
# 1     Công suất dưới 2000W\n Lực hút 900 - 1200 Pa\n...      5.949.500
# 2      Thiết kế hình chữ D độc đáo, hút sạch bụi bẩn...      9.700.000
# 3     Thiết kế hình chữ D độc đáo, hút sạch bụi bẩn ...     12.500.000
# 4                                                   NaN     11.999.000
# ...                                                 ...            ...
# 2738  Thiết kế đồng hồ hiện đại, sang trọng\nChống n...      4.432.000
# 2739                                                NaN      3.850.000
# 2740  - Chất liệu: cao cấp.\n - Kiểu dáng hiện đại, ...      1.369.000
# 2741                                                NaN      3.950.000
# 2742                                                NaN      5.499.000
#
#      priority_store  num_of_product  num_of_store lowest_price highest_price  \
# 0            Lazada             NaN           NaN          NaN           NaN
# 1            Lazada             4.0           6.0      650.000    12.999.000
# 2            Lazada             4.0           4.0    9.700.000    12.558.905
# 3            Lazada             9.0           7.0   12.255.000    18.990.000
# 4             Sendo            10.0           5.0   11.999.000    12.390.000
# ...             ...             ...           ...          ...           ...
# 2738         Shopee             NaN           NaN          NaN           NaN
# 2739         Lazada             NaN           NaN          NaN           NaN
# 2740         Shopee             4.0           4.0    1.369.000     2.440.000
# 2741         Shopee            14.0           2.0    3.950.000     4.100.000
# 2742         Shopee             9.0           3.0    5.193.000     5.262.000
#
#             category__005 category__006
# 0                     NaN           NaN
# 1                     NaN           NaN
# 2                     NaN           NaN
# 3                     NaN           NaN
# 4                     NaN           NaN
# ...                   ...           ...
# 2738  Đồng hồ nam  Orient           NaN
# 2739    Đồng hồ nam  KHÁC           NaN
# 2740    Đồng hồ nam  KHÁC           NaN
# 2741    Đồng hồ nam  KHÁC           NaN
# 2742    Đồng hồ nam  KHÁC           NaN
#
# [2743 rows x 16 columns]

# %%
pd.DataFrame(df, columns = ['category__001', 'name', 'brand', 'priority_price', 'priority_store', 'num_of_product', 'num_of_store', 'lowest_price', 'highest_price'] )
# Out:
#                   category__001  \
# 0     Điện lạnh - Điện gia dụng
# 1     Điện lạnh - Điện gia dụng
# 2     Điện lạnh - Điện gia dụng
# 3     Điện lạnh - Điện gia dụng
# 4        Máy tính - Thiết bị VP
# ...                         ...
# 2738                 Thời trang
# 2739                 Thời trang
# 2740                 Thời trang
# 2741                 Thời trang
# 2742                 Thời trang
#
#                                                    name   brand  \
# 0             Robot hút bụi thông minh Neato Botvac D85    KHÁC
# 1                      Robot hút bụi lau nhà iLife X660   Ilife
# 2     Robot hút bụi thông minh Neato Botvac Connecte...    KHÁC
# 3     Robot hút bụi thông minh Neato Botvac Connecte...    KHÁC
# 4                          Laptop Asus 14 X409FA-EK199T    Asus
# ...                                                 ...     ...
# 2738                   Đồng Hồ Nam Orient RA-KV0005B10B  Orient
# 2739                     Đồng Hồ Nam Reef Tiger RGA823G    KHÁC
# 2740                        Đồng Hồ Nam Pulsar PS9311X1    KHÁC
# 2741                     Đồng Hồ Nam Reef Tiger RGA8239    KHÁC
# 2742                          Đồng Hồ Nam Valence VC059    KHÁC
#
#      priority_price priority_store  num_of_product  num_of_store lowest_price  \
# 0        14.200.000         Lazada             NaN           NaN          NaN
# 1         5.949.500         Lazada             4.0           6.0      650.000
# 2         9.700.000         Lazada             4.0           4.0    9.700.000
# 3        12.500.000         Lazada             9.0           7.0   12.255.000
# 4        11.999.000          Sendo            10.0           5.0   11.999.000
# ...             ...            ...             ...           ...          ...
# 2738      4.432.000         Shopee             NaN           NaN          NaN
# 2739      3.850.000         Lazada             NaN           NaN          NaN
# 2740      1.369.000         Shopee             4.0           4.0    1.369.000
# 2741      3.950.000         Shopee            14.0           2.0    3.950.000
# 2742      5.499.000         Shopee             9.0           3.0    5.193.000
#
#      highest_price
# 0              NaN
# 1       12.999.000
# 2       12.558.905
# 3       18.990.000
# 4       12.390.000
# ...            ...
# 2738           NaN
# 2739           NaN
# 2740     2.440.000
# 2741     4.100.000
# 2742     5.262.000
#
# [2743 rows x 9 columns]

# %%
#df['priority_price'] = pd.to_numeric(df['priority_price'],errors='coerce')
df
# Out:
#                   category__001        category__002 category__003  \
# 0     Điện lạnh - Điện gia dụng    Gia dụng gia đình   Máy hút bụi
# 1     Điện lạnh - Điện gia dụng    Gia dụng gia đình   Máy hút bụi
# 2     Điện lạnh - Điện gia dụng    Gia dụng gia đình   Máy hút bụi
# 3     Điện lạnh - Điện gia dụng    Gia dụng gia đình   Máy hút bụi
# 4        Máy tính - Thiết bị VP               Laptop   Laptop Asus
# ...                         ...                  ...           ...
# 2738                 Thời trang  Phụ kiện thời trang       Đồng hồ
# 2739                 Thời trang  Phụ kiện thời trang       Đồng hồ
# 2740                 Thời trang  Phụ kiện thời trang       Đồng hồ
# 2741                 Thời trang  Phụ kiện thời trang       Đồng hồ
# 2742                 Thời trang  Phụ kiện thời trang       Đồng hồ
#
#            category__004                                               name  \
# 0      Máy hút bụi  KHÁC          Robot hút bụi thông minh Neato Botvac D85
# 1     Máy hút bụi  Ilife                   Robot hút bụi lau nhà iLife X660
# 2      Máy hút bụi  KHÁC  Robot hút bụi thông minh Neato Botvac Connecte...
# 3      Máy hút bụi  KHÁC  Robot hút bụi thông minh Neato Botvac Connecte...
# 4                    NaN                       Laptop Asus 14 X409FA-EK199T
# ...                  ...                                                ...
# 2738         Đồng hồ nam                   Đồng Hồ Nam Orient RA-KV0005B10B
# 2739         Đồng hồ nam                     Đồng Hồ Nam Reef Tiger RGA823G
# 2740         Đồng hồ nam                        Đồng Hồ Nam Pulsar PS9311X1
# 2741         Đồng hồ nam                     Đồng Hồ Nam Reef Tiger RGA8239
# 2742         Đồng hồ nam                          Đồng Hồ Nam Valence VC059
#
#                                                 img_url   brand  \
# 0     https://img.sosanhgia.com/images/500x0/d5d0e60...    KHÁC
# 1     https://img.sosanhgia.com/images/500x0/450781b...   Ilife
# 2     https://img.sosanhgia.com/images/500x0/c2caa7a...    KHÁC
# 3     https://img.sosanhgia.com/images/500x0/c9ecbce...    KHÁC
# 4     https://img.sosanhgia.com/images/500x0/c3290f2...    Asus
# ...                                                 ...     ...
# 2738  https://img.sosanhgia.com/images/500x0/68374a5...  Orient
# 2739  https://img.sosanhgia.com/images/500x0/8683be8...    KHÁC
# 2740  https://img.sosanhgia.com/images/500x0/eece61e...    KHÁC
# 2741  https://img.sosanhgia.com/images/500x0/5a6b0ae...    KHÁC
# 2742  https://img.sosanhgia.com/images/500x0/358f641...    KHÁC
#
#                                              short_desc priority_price  \
# 0     -- Công nghệ làm sạch SpinFlow Power Clean \n ...     14.200.000
# 1     Công suất dưới 2000W\n Lực hút 900 - 1200 Pa\n...      5.949.500
# 2      Thiết kế hình chữ D độc đáo, hút sạch bụi bẩn...      9.700.000
# 3     Thiết kế hình chữ D độc đáo, hút sạch bụi bẩn ...     12.500.000
# 4                                                   NaN     11.999.000
# ...                                                 ...            ...
# 2738  Thiết kế đồng hồ hiện đại, sang trọng\nChống n...      4.432.000
# 2739                                                NaN      3.850.000
# 2740  - Chất liệu: cao cấp.\n - Kiểu dáng hiện đại, ...      1.369.000
# 2741                                                NaN      3.950.000
# 2742                                                NaN      5.499.000
#
#      priority_store  num_of_product  num_of_store lowest_price highest_price  \
# 0            Lazada             NaN           NaN          NaN           NaN
# 1            Lazada             4.0           6.0      650.000    12.999.000
# 2            Lazada             4.0           4.0    9.700.000    12.558.905
# 3            Lazada             9.0           7.0   12.255.000    18.990.000
# 4             Sendo            10.0           5.0   11.999.000    12.390.000
# ...             ...             ...           ...          ...           ...
# 2738         Shopee             NaN           NaN          NaN           NaN
# 2739         Lazada             NaN           NaN          NaN           NaN
# 2740         Shopee             4.0           4.0    1.369.000     2.440.000
# 2741         Shopee            14.0           2.0    3.950.000     4.100.000
# 2742         Shopee             9.0           3.0    5.193.000     5.262.000
#
#             category__005 category__006
# 0                     NaN           NaN
# 1                     NaN           NaN
# 2                     NaN           NaN
# 3                     NaN           NaN
# 4                     NaN           NaN
# ...                   ...           ...
# 2738  Đồng hồ nam  Orient           NaN
# 2739    Đồng hồ nam  KHÁC           NaN
# 2740    Đồng hồ nam  KHÁC           NaN
# 2741    Đồng hồ nam  KHÁC           NaN
# 2742    Đồng hồ nam  KHÁC           NaN
#
# [2743 rows x 16 columns]

# %%
df.dtypes
# Out:
# category__001      object
# category__002      object
# category__003      object
# category__004      object
# name               object
# img_url            object
# brand              object
# short_desc         object
# priority_price     object
# priority_store     object
# num_of_product    float64
# num_of_store      float64
# lowest_price       object
# highest_price      object
# category__005      object
# category__006      object
# dtype: object

# %%
# Change the object -> float64
df['priority_price'] = df['priority_price'].apply(changeTextToInt)
df['lowest_price'] = df['lowest_price'].apply(changeTextToInt)
df['highest_price'] = df['highest_price'].apply(changeTextToInt)

# %%
#Check the changing
df.dtypes
# Out:
# category__001      object
# category__002      object
# category__003      object
# category__004      object
# name               object
# img_url            object
# brand              object
# short_desc         object
# priority_price    float64
# priority_store     object
# num_of_product    float64
# num_of_store      float64
# lowest_price      float64
# highest_price     float64
# category__005      object
# category__006      object
# dtype: object

# %%
df.describe()
# Out:
#        priority_price  num_of_product  num_of_store  lowest_price  \
# count    2.728000e+03     1943.000000   1943.000000  1.943000e+03
# mean     1.887943e+06        8.346372     10.615028  1.689015e+06
# std      8.508071e+06        7.883416     46.645617  7.750587e+06
# min      3.822000e+03        1.000000      1.000000  0.000000e+00
# 25%      6.720000e+04        3.000000      2.000000  5.500000e+04
# 50%      1.900000e+05        6.000000      3.000000  1.490000e+05
# 75%      9.208500e+05       10.000000      5.000000  6.671500e+05
# max      2.590000e+08       56.000000    650.000000  2.590000e+08
#
#        highest_price
# count   1.943000e+03
# mean    2.216640e+06
# std     1.004467e+07
# min     0.000000e+00
# 25%     8.595000e+04
# 50%     2.200000e+05
# 75%     9.800000e+05
# max     3.145800e+08

# %%
df['category__001'].value_counts()
# Out:
# Sách                         770
# Máy tính - Thiết bị VP       382
# Nhà cửa đời sống             360
# Điện lạnh - Điện gia dụng    351
# Thời trang                   211
# Sức khỏe - Làm đẹp           191
# Điện tử                      101
# Mẹ và Bé                      83
# Văn phòng phẩm                73
# Khác                          65
# Kỹ thuật số                   51
# Thực phẩm                     32
# Bách hóa                      31
# Thiết bị di động              29
# Thể thao / Dã ngoại            7
# Ô tô / Xe máy                  6
# Name: category__001, dtype: int64

# %%
df['brand'].value_counts()
# Out:
# KHÁC                358
# Nhiều Tác Giả        94
# TOTAL                33
# Huy Hoàng            31
# Stabilo              30
#                    ...
# Chu Châu Bân          1
# Helen Stephenson      1
# Earth Choice          1
# Courtney Carver       1
# Mark Twain            1
# Name: brand, Length: 688, dtype: int64

# %%
df['priority_store'].value_counts()
# Out:
# Shopee               797
# Lazada               788
# Tiki                 731
# Sendo                117
# FAHASA                34
# Bookbuy               30
# Fado                  28
# An Phát               23
# Yes24                 22
# HanoiComputer         19
# MediaMart             15
# Shop Vnexpress        14
# Phong Vũ              12
# Vinabook              11
# Phương Nam Book       11
# US Express            10
# Phúc Anh               9
# Điện máy XANH          8
# Điện máy Chợ Lớn       7
# AeonEshop              7
# Pico                   6
# Thiên Hòa              5
# Thành Nhân             4
# HC                     3
# Nguyễn Kim             3
# Samnec                 3
# Bình Minh Digital      2
# CoopMart               2
# Mai Hoàng              2
# Tân Doanh              2
# FPT Shop               1
# BiboMart               1
# Bách hóa Xanh          1
# Name: priority_store, dtype: int64

# %%
int(df['priority_price'].max())
# Get the maximum priority price
# Out:
# 259000000

# %%
print("Max highest price:", int(df['highest_price'].max()))
print("Min highest price:", int(df['highest_price'].min()))
print("Max lowest price:", int(df['lowest_price'].max()))
print("Min lowest price:", int(df['lowest_price'].min()))
# Out:
# Max highest price: 314580000
# Min highest price: 0
# Max lowest price: 259000000
# Min lowest price: 0

# %%
CountStore = pd.DataFrame(data=df['priority_store'].value_counts())
CountStore.plot.bar()
#Draw a bar chat using value_counts of priority_store
print(CountStore.keys())
# Out:
# Index(['priority_store'], dtype='object')

# %%
df_Shopee = df.groupby('priority_store').get_group('Shopee')
df_Shopee.describe()
# Out:
#        priority_price  num_of_product  num_of_store  lowest_price  \
# count    7.970000e+02      666.000000    666.000000  6.660000e+02
# mean     6.642053e+05        9.563063      4.818318  5.923288e+05
# std      1.917770e+06        8.500142     16.525897  1.879676e+06
# min      3.822000e+03        1.000000      1.000000  0.000000e+00
# 25%      5.500000e+04        4.000000      2.000000  5.000000e+04
# 50%      1.350000e+05        7.000000      3.000000  1.180750e+05
# 75%      3.980000e+05       12.000000      5.000000  3.200000e+05
# max      2.600000e+07       47.000000    399.000000  2.596000e+07
#
#        highest_price
# count   6.660000e+02
# mean    7.916655e+05
# std     2.257018e+06
# min     0.000000e+00
# 25%     7.925000e+04
# 50%     1.905000e+05
# 75%     4.616750e+05
# max     2.859000e+07

# %%
plt.xlabel('Priority Store')
plt.ylabel('Number')
plt.suptitle('Number of Priority Store in sosanhgia')

plt.bar(df['priority_store'], df['lowest_price'], label='Hits')
plt.bar(df['priority_store'], df['highest_price'], label='Home Runs')

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-1b2a40134961> in <module>
#       3 plt.suptitle('Number of Priority Store in sosanhgia')
#       4
# ----> 5 plt.bar(df['priority_store'], df['lowest_price'], label='Hits')
#       6 plt.bar(df['priority_store'], df['highest_price'], label='Home Runs')
#       7
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2439     return gca().bar(
#    2440         x, height, width=width, bottom=bottom, align=align,
# -> 2441         **({"data": data} if data is not None else {}), **kwargs)
#    2442
#    2443
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2345
#    2346         if orientation == 'vertical':
# -> 2347             self._process_unit_info(xdata=x, ydata=height, kwargs=kwargs)
#    2348             if log:
#    2349                 self.set_yscale('log', nonposy='clip')
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _process_unit_info(self, xdata, ydata, kwargs)
#    2123             return kwargs
#    2124
# -> 2125         kwargs = _process_single_axis(xdata, self.xaxis, 'xunits', kwargs)
#    2126         kwargs = _process_single_axis(ydata, self.yaxis, 'yunits', kwargs)
#    2127         return kwargs
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _process_single_axis(data, axis, unit_name, kwargs)
#    2106                 # We only need to update if there is nothing set yet.
#    2107                 if not axis.have_units():
# -> 2108                     axis.update_units(data)
#    2109
#    2110             # Check for units in the kwargs, and if present update axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in update_units(self, data)
#    1491         neednew = self.converter != converter
#    1492         self.converter = converter
# -> 1493         default = self.converter.default_units(data, self)
#    1494         if default is not None and self.units is None:
#    1495             self.set_units(default)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\category.py in default_units(data, axis)
#     113         # default_units->axis_info->convert
#     114         if axis.units is None:
# --> 115             axis.set_units(UnitData(data))
#     116         else:
#     117             axis.units.update(data)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\category.py in __init__(self, data)
#     179         self._counter = itertools.count()
#     180         if data is not None:
# --> 181             self.update(data)
#     182
#     183     @staticmethod
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\category.py in update(self, data)
#     217             # OrderedDict just iterates over unique values in data.
#     218             if not isinstance(val, (str, bytes)):
# --> 219                 raise TypeError("{val!r} is not a string".format(val=val))
#     220             if convertible:
#     221                 # this will only be called so long as convertible is True.
#
# TypeError: nan is not a string
